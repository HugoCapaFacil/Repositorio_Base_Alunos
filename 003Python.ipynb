# %% [markdown]
# # Strings

# %% [markdown]
# São Usadas principalmente para armazenar informaçôes de texto. Nelas temos uma sequencia de caracteres que formam um texto. o Python permite formar strings com aspas simples ou duplas

# %%
"João"=="JOÃO" # o python diferencia letras maiusculas de minusculas
# Out:
# False

# %%
nome = "Hugo"
Sobrenome = "Otton"

# %%
print(nome + " "+ Sobrenome)
# Out:
# Hugo Otton

# %% [markdown]
# ## f-strings

# %% [markdown]
# String Literais formadas

# %%
Idade = 15

# %%
print(nome, Sobrenome, Idade) # as virgulas s~sao maneiras de chamar variaveis diferentes
# Out:
# Hugo Otton 15

# %%
print(f"{nome} {Sobrenome} tem {Idade} anos.") # f na frente do print informa q estamos formatando o print
# Out:
# Hugo Otton tem 15 anos.

# %% [markdown]
# ## String são objetos interaveis

# %%
nome = "Messi" # o python entende uma palavra como uma lista de letras então podemos percorrer a lista e percorrer o que desejamos, uma lista sempre inicia pelo indice 0

# %%
print(nome)
# Out:
# Messi

# %%
nome[0]
# Out:
# 'M'

# %%
nome[-1] # podemos acessar o ultimo elemento de uma lista atraves do indice -1
# Out:
# 'i'

# %% [markdown]
# # entrada de dados com a função input()

# %% [markdown]
# é muito comum em programação em q o usuario passe algum tipo de dado

# %%
input("Digite seu Nome: ")
# Out:
# Digite seu Nome: Messi ronaldo 2
# 'Messi ronaldo 2'

# %%
nome = input("Digite seu nome: ")
# Out:
# Digite seu nome: Cristiano ronaldo

# %%
print(nome)
# Out:
# Cristiano ronaldo

# %%
# para fazer a operação matematica precisamos informar qual tipo é o dado
num1 = input("Digite seu nomero")
num2 = input("Digite o outro numero")

# %%
num1 =int( input("Digite seu nomero: "))
num2 = int( input("Digite o outro numero:"))
print(num1 + num2)
# Out:
# Digite seu nomero: 68
# Digite o outro numero:1
# 69

# %%
soma = num1 + num2
print(soma)
# Out:
# 69

# %%
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda media: "))
media =(nota1 +nota2)/2
print(f"O aluno(a) teve notas {nota1}, {nota2} e sua media é {media}")
# Out:
# Digite a primeira nota: 69
# Digite a segunda media: 69
# O aluno(a) teve notas 69.0, 69.0 e sua media é 69.0

# %% [markdown]
# # operadores aritimeticos

# %% [markdown]
# Adição (+)

# %%
print(10 + 20)
print(10+20.5)
print(10 + 30 + 40)
# Out:
# 30
# 30.5
# 80

# %% [markdown]
# Subtração (-)

# %%
print(-89 + 63)
print(23 - 17)
print(34 - 67)
# Out:
# -26
# 6
# -33

# %% [markdown]
# Multiplicação (*)

# %%
print(10*2)
# Out:
# 20

# %% [markdown]
# Divisão (/) ou (//)

# %%
print(10/2)
print(11/2)
print(11//2) # com "//" é o numero inteiro apenas
# Out:
# 5.0
# 5.5
# 5

# %% [markdown]
# Exponenciação

# %%
print(2**3) # a Potenciação vem a partir dos dois asteriscos
print(2**-2)
# Out:
# 8
# 0.25

# %% [markdown]
# # Precendencia

# %% [markdown]
# 1.   ( )
#
# 2.   expoentes
#
# 3. multiplicação e / ou //
#
# 4. Adição e -

# %%
5 + 25 * 2
# Out:
# 55

# %% [markdown]
# Radiciação

# %%
4** 0.5
# Out:
# 2.0

# %% [markdown]
# # Hora de pretica

# %% [markdown]
# 1) crie um codigo q receba o nome do aulo 2 notas e informe a media do aluno.
# obs: no seu print vc deve apresentar o nome do aluno as duas notas e a media

# %%
nome1 = input("digite seu Nome aqui: ")
idade1 = input("digite sua idade aqui: ")
num3 = float(input("Coloque sua primeira nota: "))
num4 = float(input("Coloque sua segunda nota: "))
media1 = (num3 + num4)/2
print(f"Seu nome é {nome1}, Você tem {idade1} anos e sua media é {media1}")
# Out:
# digite seu Nome aqui: Hugo
# digite sua idade aqui: 15
# Coloque sua primeira nota: 10
# Coloque sua segunda nota: 5
# Seu nome é Hugo, Você tem 15 anos e sua media é 7.5

# %%
lado1 = float(input("Digite o tamanho do lado: "))
lado2 = float(input("Digite o tamanho do segundo lado: "))
Perimetro = (lado1*2 + lado2*2)
print(f"O tamanho do seu Perimetro é {Perimetro}")
# Out:
# Digite o tamanho do lado: 10
# Digite o tamanho do segundo lado: 12.5
# O tamanho do seu Perimetro é 45.0

# %%
num5 = int(input("Digite o numero qual vc quer saber a raiz quadrada: "))
raiz = (num5**0.5)
print(f"O Resultado é: {raiz}")
# Out:
# Digite o numero qual vc quer saber a raiz quadrada: 144
# O Resultado é: 12.0

# %%
operação = input("Qual tipo de operação você gostaria de realizar? ")
operação== "Adição"
operação== "Subtração"
operação== "Multiplicação"
operação== "Divisão"
with
# Out:
#   File "/tmp/ipython-input-4069715747.py", line 6
#     with
#         ^
# SyntaxError: invalid syntax

# %%
num8 = float(input("Digite o primeiro numero: "))
num9 = float(input("Digite o segundo numero: "))
subtração2 = (num8 - num9)
print(f"seu resultado é {subtração2}")
# Out:
# Digite o primeiro numero: 10
# Digite o segundo numero: 2.5
# seu resultado é 7.5

# %%
num10 = float(input("Digite a base: "))
num11 = float(input("Digite o expoente: "))
rsultado2 = (num10** num11)
print(rsultado2)
# Out:
# Digite a base: 2
# Digite o expoente: 3
# 8.0

# %%
segunda1 = int(input("Digite quantas horas vc trabalhou na Segunda: "))
terca2 = int(input("Digite quantas horas vc trabalhou na terça: "))
quarta = int(input("Digite quantas horas vc trabalhou na Quarta: "))
quinta = int(input("Digite quantas horas vc trabalhou na Quinta: "))
Sexta = int(input("Digite quantas horas vc trabalhou na Sexta: "))
Sabado = int(input("Digite quantas horas vc trabalhou no Sabado: "))
Totaldehoras = (segunda1 + terca2 + quarta + quinta + Sexta + Sabado)
print(f"O total de horas trabalhadas na sua semana foi: {Totaldehoras}h")
# Out:
# Digite quantas horas vc trabalhou na Segunda: 1
# Digite quantas horas vc trabalhou na terça: 2
# Digite quantas horas vc trabalhou na Quarta: 3
# Digite quantas horas vc trabalhou na Quinta: 4
# Digite quantas horas vc trabalhou na Sexta: 3
# Digite quantas horas vc trabalhou no Sabado: 2
# O total de horas trabalhadas na sua semana foi: 15h

# %%
n1 = float(input("Digite um numero: "))
n2 = float(input("Digite outro numero: "))
soma1 = n1 + n2
subtração3 = n1 - n2
Multiplicação1 = n1 * n2
divisao = n1/ n2
print(f"O seus resultados são: {soma1}, {subtração3}, {Multiplicação1}, {divisao}")
# Out:
# Digite um numero: 2
# Digite outro numero: 4
# O seus resultados são: 6.0, -2.0, 8.0, 0.5
