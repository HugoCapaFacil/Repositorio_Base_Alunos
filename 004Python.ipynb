# %% [markdown]
# # Operadores Relacionais

# %% [markdown]
# ## > maior
# ## >= maior igual
# ## < menor
# ## <= menor igual
# ## != diferente
# ## == igual

# %%
10 > 20

# %%
10 < 20

# %%
5 + 1 != 6

# %%
3 + 1 >= 4

# %%
nome1 = "messi"
nome2 = "cr7"

# %%
nome1 == nome2
# Out:
#   File "/tmp/ipython-input-2487383800.py", line 1
#     nome1 == nome2 NOT
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## operadores logicos

# %% [markdown]
# - AND (e)
# - OR (ou)
# - NOT (negativo)

# %%
(10 > 20) and (20 > 40)
# Out:
# False

# %% [markdown]
# # AND
#
# True + True = True
#
# True + false = false
#
# false + true = false
#
# false + false = false

# %%
(10>20) and (20>30)
# Out:
# False

# %%
(10<20) and (20<30)
# Out:
# True

# %% [markdown]
# # Or
#
# True + True = True
#
# True + false = True
#
# false + true = True
#
# false + false = false

# %%
(1 <2) or (3>6)
# Out:
# True

# %% [markdown]
# # Not
#
# not = true = false
#
# not false = true

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True
